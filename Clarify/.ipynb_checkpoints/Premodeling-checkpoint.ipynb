# %%
import sagemaker
session = sagemaker.Session(default_bucket = "demo-output-bucket")
role = sagemaker.get_execution_role()
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from sagemaker import clarify

clarify_processor = clarify.SageMakerClarifyProcessor(
    role=role,
    instance_count=1,
    instance_type='ml.c4.xlarge',
    sagemaker_session=session,
)

# %%
dataset_s3_uri = "s3://demo-output-bucket/Training_Pipeline_Output/2023-08-22T04:50:42.566Z/TrainProcessingOutput/train.csv"
clarify_job_output_s3_uri = "s3://demo-output-bucket/Clarify_Outputs"

# %%
data_config = clarify.DataConfig(
    s3_data_input_path=dataset_s3_uri,
    dataset_type='text/csv',
    headers=['Account length', 'Number vmail messages', 'Total day minutes', 'Total day calls', 'Total eve minutes', 'Total eve calls', 
             'Total night minutes', 'Total night calls', 'Total intl minutes', 'Total intl calls', 'Customer service calls', 'Churn', 'Total_minutes',
             'Total_calls', 'Minutes_per_call_overall', 'Minutes*call_overall', 'Minutes_per_call_int', 'Minutes*call_int', 'Minutes_per_call_day',
             'Minutes*call_day', 'Minutes_per_call_eve', 'Minutes*call_eve', 'Minutes_per_call_night', 'Minutes*call_night', 'Total_charge',
       'Day_minutes_per_customer_service_calls',
       'Day_minutes*customer_service_calls', 'Total_day_minutes_wholenum',
       'Total_day_minutes_decimalnum', 'Total_minutes_wholenum',
       'Total_minutes_decimalnum', 'Voice_and_Int_plan', 'Only_Int_plan',
       'Only_vmail_plan', 'No_plans', 'State_AL', 'State_AR', 'State_AZ',
       'State_CA', 'State_CO', 'State_CT', 'State_DC', 'State_DE', 'State_FL',
       'State_GA', 'State_HI', 'State_IA', 'State_ID', 'State_IL', 'State_IN',
       'State_KS', 'State_KY', 'State_LA', 'State_MA', 'State_MD', 'State_ME',
       'State_MI', 'State_MN', 'State_MO', 'State_MS', 'State_MT', 'State_NC',
       'State_ND', 'State_NE', 'State_NH', 'State_NJ', 'State_NM', 'State_NV',
       'State_NY', 'State_OH', 'State_OK', 'State_OR', 'State_PA', 'State_RI',
       'State_SC', 'State_SD', 'State_TN', 'State_TX', 'State_UT', 'State_VA',
       'State_VT', 'State_WA', 'State_WI', 'State_WV', 'State_WY',
       'Area code_415', 'Area code_510', 'International plan_Yes',
       'Voice mail plan_Yes', 'Account_length_bins_q2',
       'Account_length_bins_q3', 'Account_length_bins_q4', 'zero_vmails_Yes',
       'Customer_service_calls_bins_q2', 'Customer_service_calls_bins_q3',
       'Customer_service_calls_bins_q4'],
    label='Churn',
    s3_output_path=clarify_job_output_s3_uri,
)

# %%
bias_config = clarify.BiasConfig(
    label_values_or_threshold=[1],
    facet_name='Total eve calls',
    facet_values_or_threshold=[0.5],
)

# %%
clarify_processor.run_pre_training_bias(
     data_config=data_config,
    data_bias_config=bias_config,
    methods="all",
)
# Out:
# INFO:sagemaker.clarify:Analysis Config: {'dataset_type': 'text/csv', 'headers': ['Account length', 'Number vmail messages', 'Total day minutes', 'Total day calls', 'Total eve minutes', 'Total eve calls', 'Total night minutes', 'Total night calls', 'Total intl minutes', 'Total intl calls', 'Customer service calls', 'Churn', 'Total_minutes', 'Total_calls', 'Minutes_per_call_overall', 'Minutes*call_overall', 'Minutes_per_call_int', 'Minutes*call_int', 'Minutes_per_call_day', 'Minutes*call_day', 'Minutes_per_call_eve', 'Minutes*call_eve', 'Minutes_per_call_night', 'Minutes*call_night', 'Total_charge', 'Day_minutes_per_customer_service_calls', 'Day_minutes*customer_service_calls', 'Total_day_minutes_wholenum', 'Total_day_minutes_decimalnum', 'Total_minutes_wholenum', 'Total_minutes_decimalnum', 'Voice_and_Int_plan', 'Only_Int_plan', 'Only_vmail_plan', 'No_plans', 'State_AL', 'State_AR', 'State_AZ', 'State_CA', 'State_CO', 'State_CT', 'State_DC', 'State_DE', 'State_FL', 'State_GA', 'State_HI', 'State_IA', 'State_ID', 'State_IL', 'State_IN', 'State_KS', 'State_KY', 'State_LA', 'State_MA', 'State_MD', 'State_ME', 'State_MI', 'State_MN', 'State_MO', 'State_MS', 'State_MT', 'State_NC', 'State_ND', 'State_NE', 'State_NH', 'State_NJ', 'State_NM', 'State_NV', 'State_NY', 'State_OH', 'State_OK', 'State_OR', 'State_PA', 'State_RI', 'State_SC', 'State_SD', 'State_TN', 'State_TX', 'State_UT', 'State_VA', 'State_VT', 'State_WA', 'State_WI', 'State_WV', 'State_WY', 'Area code_415', 'Area code_510', 'International plan_Yes', 'Voice mail plan_Yes', 'Account_length_bins_q2', 'Account_length_bins_q3', 'Account_length_bins_q4', 'zero_vmails_Yes', 'Customer_service_calls_bins_q2', 'Customer_service_calls_bins_q3', 'Customer_service_calls_bins_q4'], 'label': 'Churn', 'label_values_or_threshold': ['FALSE'], 'facet': [{'name_or_index': 'Total eve calls', 'value_or_threshold': [0.5]}], 'methods': {'report': {'name': 'report', 'title': 'Analysis Report'}, 'pre_training_bias': {'methods': 'all'}}}
# INFO:sagemaker:Creating processing-job with name Clarify-Pretraining-Bias-2023-08-21-04-36-06-391
# .......................................2023-08-21 04:42:35,013 logging.conf not found when configuring logging, using default logging configuration.
# 2023-08-21 04:42:35,014 Starting SageMaker Clarify Processing job
# 2023-08-21 04:42:35,015 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2023-08-21 04:42:35,015 Analysis result path: /opt/ml/processing/output
# 2023-08-21 04:42:35,017 This host is algo-1.
# 2023-08-21 04:42:35,017 This host is the leader.
# 2023-08-21 04:42:35,017 Number of hosts in the cluster is 1.
# 2023-08-21 04:42:35,019 Running Python / Pandas based analyzer.
# 2023-08-21 04:42:35,019 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2023-08-21 04:42:35,033 Loading dataset...
# /usr/local/lib/python3.9/site-packages/analyzer/data_loading/csv_data_loader.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_tmp, ignore_index=True)
# 2023-08-21 04:42:35,066 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 95 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Account length                          1786 non-null   float64
#  1   Number vmail messages                   1786 non-null   float64
#  2   Total day minutes                       1786 non-null   float64
#  3   Total day calls                         1786 non-null   float64
#  4   Total eve minutes                       1786 non-null   float64
#  5   Total eve calls                         1786 non-null   float64
#  6   Total night minutes                     1786 non-null   float64
#  7   Total night calls                       1786 non-null   float64
#  8   Total intl minutes                      1786 non-null   float64
#  9   Total intl calls                        1786 non-null   float64
#  10  Customer service calls                  1786 non-null   float64
#  11  Total_minutes                           1786 non-null   float64
#  12  Total_calls                             1786 non-null   float64
#  13  Minutes_per_call_overall                1786 non-null   float64
#  88  Account_length_bins_q2                  1786 non-null   int64
#  89  Account_length_bins_q3                  1786 non-null   int64
#  90  Account_length_bins_q4                  1786 non-null   int64
#  91  zero_vmails_Yes                         1786 non-null   int64
#  92  Customer_service_calls_bins_q2          1786 non-null   int64
#  93  Customer_service_calls_bins_q3          1786 non-null   int64
#  94  Customer_service_calls_bins_q4          1786 non-null   int64
# dtypes: float64(34), int64(61)
# memory usage: 1.3 MB
# 2023-08-21 04:42:35,067 Calculated global analysis with predictor
# 2023-08-21 04:42:35,067 =====================================
# 2023-08-21 04:42:35,067 Calculating pre-training bias metrics
# 2023-08-21 04:42:35,067 =====================================
# 2023-08-21 04:42:35,067 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-21 04:42:35,068 Data type of the elements in `positive_label_values` and in `label` must match. Converted positive_label_values from ['FALSE'] to [True]
# 2023-08-21 04:42:35,070 Column Total eve calls with data uniqueness fraction 0.06550951847704367 is classifed as a CONTINUOUS column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:591: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2023-08-21 04:42:35,072 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-21 04:42:35,073 Data type of the elements in `positive_label_values` and in `label` must match. Converted positive_label_values from ['FALSE'] to [True]
# 2023-08-21 04:42:35,075 Threshold Interval indices: IntervalIndex([(0.5, 0.9352941176470588]], dtype='interval[float64, right]')
# 2023-08-21 04:42:35,085 CDDL metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/report.py", line 357, in _continuous_metric_call_wrapper
#     metric_value = smclarify.bias.metrics.call_metric(
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/pretraining.py", line 195, in CDDL
#     return common.CDD(feature, sensitive_facet_index, positive_label_index, group_variable)
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/common.py", line 100, in CDD
#     raise ValueError("Group variable is empty or not provided")
# ValueError: Group variable is empty or not provided
# 2023-08-21 04:42:35,173 ======================================
# 2023-08-21 04:42:35,173 Calculating bias statistics for report
# 2023-08-21 04:42:35,174 ======================================
# 2023-08-21 04:42:35,174 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-21 04:42:35,175 Data type of the elements in `positive_label_values` and in `label` must match. Converted positive_label_values from ['FALSE'] to [True]
# 2023-08-21 04:42:35,176 Column Total eve calls with data uniqueness fraction 0.06550951847704367 is classifed as a CONTINUOUS column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:591: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2023-08-21 04:42:35,178 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-21 04:42:35,178 Data type of the elements in `positive_label_values` and in `label` must match. Converted positive_label_values from ['FALSE'] to [True]
# 2023-08-21 04:42:35,180 Threshold Interval indices: IntervalIndex([(0.5, 0.9352941176470588]], dtype='interval[float64, right]')
# 2023-08-21 04:42:35,202 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-21 04:42:35,202 Data type of the elements in `positive_label_values` and in `label` must match. Converted positive_label_values from ['FALSE'] to [True]
# 2023-08-21 04:42:35,203 Model performance computations failed.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/analyzer/bias/bias_stats_analyzer.py", line 118, in generate_model_performance_report
#     metrics_result: Dict[str, Any] = bias.model_performance_report(
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/report.py", line 442, in model_performance_report
#     predicted_label_column.series, positive_label_values
# AttributeError: 'NoneType' object has no attribute 'series'
# 2023-08-21 04:42:35,204 Converting Pandas DataFrame to SparkDataFrame for computing report metadata
# 04:42:38.463 [main] WARN  o.a.hadoop.util.NativeCodeLoader - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 04:42:45.289 [Thread-4] WARN  o.a.spark.sql.catalyst.util.package - Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# #015[Stage 0:>                                                          (0 + 4) / 4]#015#015                                                                                #0152023-08-21 04:42:50,119 Report Metadata: Could not find predicted_label in Dataframe
# 2023-08-21 04:42:52,320 Calculated global analysis without predictor
# 2023-08-21 04:42:53,057 ['jupyter', 'nbconvert', '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 528121 bytes to /opt/ml/processing/output/report.html
# 2023-08-21 04:42:54,300 ['wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2023-08-21 04:42:55,398 Collected analyses:
# {
#     "version": "1.0",
#     "pre_training_bias_metrics": {
#         "label": "Churn",
#         "facets": {
#             "Total eve calls": [
#                 {
#                     "value_or_threshold": "(0.5, 0.9352941176470588]",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": null,
#                             "error": "Group variable is empty or not provided"
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": -0.5375139977603584
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.021707118785149082
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.0004920383753821561
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.0019268737544213925
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.021707118785149082
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.030698501786001614
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.021707118785149082
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "FALSE"
#     }
# }
# 2023-08-21 04:42:55,399 exit_message: Completed: SageMaker XAI Analyzer ran successfully

# %%
from sagemaker.model import Model

model = Model(
    entry_point = "Evaluation.py",
    source_dir = "code", 
    role = role,
    image_uri = "720646828776.dkr.ecr.ap-south-1.amazonaws.com/sagemaker-scikit-learn:1.0-1-cpu-py3",
    model_data = "s3://demo-output-bucket/Training_Pipeline_Output/2023-08-22T04:50:42.566Z/HPTuningOutputs/Decision_Tree/7zzd5fdyf7vp-hptuning-RdmmsC70BE-001-b790a6b3/output/model.tar.gz"
)

# %%
predictor = model.deploy(initial_instance_count=1, instance_type="ml.c5.xlarge", endpoint_name = "endpoint-2023")
# Out:
# ---!

# %%
from sagemaker import clarify

model_config = clarify.ModelConfig(
    model_name="sagemaker-scikit-learn-2023-08-22-06-39-13-777",
    instance_type='ml.c5.xlarge',
    instance_count=1
)

# %%
predicted_label_config = clarify.ModelPredictedLabelConfig(
    label=0,
)

# %%
clarify_processor.run_post_training_bias(
    data_config=data_config,
    data_bias_config=bias_config,
    model_config=model_config,
    model_predicted_label_config=predicted_label_config,
    methods="all",
)
# Out:
# INFO:sagemaker:Creating processing-job with name Clarify-Posttraining-Bias-2023-08-22-06-41-15-537
# ......................................2023-08-22 06:47:30,986 logging.conf not found when configuring logging, using default logging configuration.
# 2023-08-22 06:47:30,987 Starting SageMaker Clarify Processing job
# 2023-08-22 06:47:30,988 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2023-08-22 06:47:30,988 Analysis result path: /opt/ml/processing/output
# 2023-08-22 06:47:30,989 This host is algo-1.
# 2023-08-22 06:47:30,989 This host is the leader.
# 2023-08-22 06:47:30,989 Number of hosts in the cluster is 1.
# Error retrieving tags. resource_arn: arn:aws:sagemaker:ap-south-1:720541911643:processing-job/clarify-posttraining-bias-2023-08-22-06-41-15-537
# 2023-08-22 06:47:31,262 Failed to fetch tags for ProcessingJobArn: arn:aws:sagemaker:ap-south-1:720541911643:processing-job/clarify-posttraining-bias-2023-08-22-06-41-15-537
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/analyzer/data_loading/data_loader_util.py", line 144, in load_configs
#     tags = sagemaker_session.list_tags(resource_arn=processing_job_arn)
#   File "/usr/local/lib/python3.9/site-packages/sagemaker/session.py", line 3567, in list_tags
#     raise error
#   File "/usr/local/lib/python3.9/site-packages/sagemaker/session.py", line 3547, in list_tags
#     list_tags_response = self.sagemaker_client.list_tags(
#   File "/usr/local/lib/python3.9/site-packages/botocore/client.py", line 530, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/usr/local/lib/python3.9/site-packages/botocore/client.py", line 960, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.exceptions.ClientError: An error occurred (ValidationException) when calling the ListTags operation: Resource does not exist.
# 2023-08-22 06:47:31,265 Running Python / Pandas based analyzer.
# 2023-08-22 06:47:31,265 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2023-08-22 06:47:31,278 Loading dataset...
# /usr/local/lib/python3.9/site-packages/analyzer/data_loading/csv_data_loader.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_tmp, ignore_index=True)
# 2023-08-22 06:47:31,309 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 95 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Account length                          1786 non-null   float64
#  1   Number vmail messages                   1786 non-null   float64
#  2   Total day minutes                       1786 non-null   float64
#  3   Total day calls                         1786 non-null   float64
#  4   Total eve minutes                       1786 non-null   float64
#  5   Total eve calls                         1786 non-null   float64
#  6   Total night minutes                     1786 non-null   float64
#  7   Total night calls                       1786 non-null   float64
#  8   Total intl minutes                      1786 non-null   float64
#  9   Total intl calls                        1786 non-null   float64
#  10  Customer service calls                  1786 non-null   float64
#  11  Total_minutes                           1786 non-null   float64
#  12  Total_calls                             1786 non-null   float64
#  13  Minutes_per_call_overall                1786 non-null   float64
#  14  Minutes*call_overall                    1786 non-null   float64
#  15  Minutes_per_call_int                    1786 non-null   float64
#  16  Minutes*call_int                        1786 non-null   float64
#  17  Minutes_per_call_day                    1786 non-null   float64
#  18  Minutes*call_day                        1786 non-null   float64
#  19  Minutes_per_call_eve                    1786 non-null   float64
#  20  Minutes*call_eve                        1786 non-null   float64
#  21  Minutes_per_call_night                  1786 non-null   float64
#  22  Minutes*call_night                      1786 non-null   float64
# 2023-08-22 06:47:31,310 predictor label configuration will be used as probability configuration
# 2023-08-22 06:47:31,398 Spinning up shadow endpoint
# 2023-08-22 06:47:31,398 Creating endpoint-config with name sm-clarify-config-1692686851-d279
# 2023-08-22 06:47:31,634 Creating endpoint: 'sm-clarify-sagemaker-scikit-learn-2023-08-22-06-1692686851-346d'
# 2023-08-22 06:47:31,694 No endpoints ruleset found for service sagemaker-internal, falling back to legacy endpoint routing.
# 2023-08-22 06:47:32,177 Using endpoint name: sm-clarify-sagemaker-scikit-learn-2023-08-22-06-1692686851-346d
# 2023-08-22 06:47:32,178 Waiting for endpoint ...
# 2023-08-22 06:47:32,178 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2023-08-22 06:49:32,546 Endpoint is in service after 120 seconds
# 2023-08-22 06:49:32,547 Endpoint ready.
# 2023-08-22 06:49:32,547 ======================================
# 2023-08-22 06:49:32,547 Calculating post-training bias metrics
# 2023-08-22 06:49:32,547 ======================================
# 2023-08-22 06:49:32,547 Getting predictions from the endpoint
# 2023-08-22 06:49:35,339 We assume a prediction above 0.500 indicates 1 and below or equal indicates 0.
# 2023-08-22 06:49:35,340 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-22 06:49:35,342 Column Total eve calls with data uniqueness fraction 0.06550951847704367 is classifed as a CONTINUOUS column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:591: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2023-08-22 06:49:35,344 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-22 06:49:35,345 Column None with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-22 06:49:35,347 Threshold Interval indices: IntervalIndex([(0.5, 0.9352941176470588]], dtype='interval[float64, right]')
# 2023-08-22 06:49:35,370 CDDPL metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/report.py", line 357, in _continuous_metric_call_wrapper
#     metric_value = smclarify.bias.metrics.call_metric(
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/posttraining.py", line 277, in CDDPL
#     return common.CDD(feature, sensitive_facet_index, positive_predicted_label_index, group_variable)
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/common.py", line 100, in CDD
#     raise ValueError("Group variable is empty or not provided")
# ValueError: Group variable is empty or not provided
# 2023-08-22 06:49:35,710 Calculated global analysis with predictor
# 2023-08-22 06:49:35,710 Stop using endpoint: sm-clarify-sagemaker-scikit-learn-2023-08-22-06-1692686851-346d
# 2023-08-22 06:49:35,710 Deleting endpoint configuration with name: sm-clarify-config-1692686851-d279
# 2023-08-22 06:49:35,857 Deleting endpoint with name: sm-clarify-sagemaker-scikit-learn-2023-08-22-06-1692686851-346d
# 2023-08-22 06:49:35,939 Model endpoint delivered 0.63220 requests per second and a total of 2 requests over 3 seconds
# 2023-08-22 06:49:35,939 ======================================
# 2023-08-22 06:49:35,939 Calculating bias statistics for report
# 2023-08-22 06:49:35,939 ======================================
# 2023-08-22 06:49:35,939 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-22 06:49:35,942 Column Total eve calls with data uniqueness fraction 0.06550951847704367 is classifed as a CONTINUOUS column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:591: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2023-08-22 06:49:35,944 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-22 06:49:35,945 Column None with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-22 06:49:35,946 Threshold Interval indices: IntervalIndex([(0.5, 0.9352941176470588]], dtype='interval[float64, right]')
# 2023-08-22 06:49:35,979 Column Churn with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-22 06:49:35,980 Column None with data uniqueness fraction 0.0011198208286674132 is classifed as a CATEGORICAL column
# 2023-08-22 06:49:35,988 Converting Pandas DataFrame to SparkDataFrame for computing report metadata
# -!06:49:38.343 [main] WARN  o.a.hadoop.util.NativeCodeLoader - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 06:49:44.899 [Thread-4] WARN  o.a.spark.sql.catalyst.util.package - Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# #015[Stage 0:>                                                          (0 + 4) / 4]#015#015                                                                                #0152023-08-22 06:49:52,391 Calculated global analysis without predictor
# 2023-08-22 06:49:52,391 Stop using endpoint: None
# 2023-08-22 06:49:53,130 ['jupyter', 'nbconvert', '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 553816 bytes to /opt/ml/processing/output/report.html
# 2023-08-22 06:49:54,377 ['wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2023-08-22 06:49:55,622 Collected analyses:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "Churn",
#         "facets": {
#             "Total eve calls": [
#                 {
#                     "value_or_threshold": "(0.5, 0.9352941176470588]",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": 0.0070858073993606
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": null,
#                             "error": "Group variable is empty or not provided"
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": -0.015119047619047699
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": -0.0729761904761903
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.012177830630960229
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 1.0966709152706968
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.011235360612574921
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.01027282914446448
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 0.09322651128914786
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.011452081632652954
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.042132258655431465
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": 0.0019208797486431894
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": 26.0
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }
# 2023-08-22 06:49:55,623 exit_message: Completed: SageMaker XAI Analyzer ran successfully

# %%
https://docs.aws.amazon.com/sagemaker/latest/dg/clarify-processing-job-run.html
